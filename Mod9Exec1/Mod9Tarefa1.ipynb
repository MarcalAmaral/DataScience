# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
#  18  APGAR1        26932 non-null  float64
#  19  APGAR5        26925 non-null  float64
#  20  RACACOR       26381 non-null  object
#  21  PESO          27028 non-null  int64
#  22  IDANOMAL      26437 non-null  float64
#  23  DTCADASTRO    27028 non-null  object
#  24  CODANOMAL     214 non-null    object
#  25  NUMEROLOTE    27028 non-null  int64
#  26  VERSAOSIST    27028 non-null  object
#  27  DTRECEBIM     27028 non-null  object
#  28  DIFDATA       27028 non-null  int64
#  29  DTRECORIGA    0 non-null      float64
#  30  NATURALMAE    26730 non-null  float64
#  31  CODMUNNATU    26730 non-null  float64
#  32  CODUFNATU     26730 non-null  float64
#  33  ESCMAE2010    26779 non-null  float64
#  34  SERIESCMAE    14318 non-null  float64
#  35  DTNASCMAE     26988 non-null  float64
#  36  RACACORMAE    26367 non-null  float64
#  37  QTDGESTANT    25816 non-null  float64
#  38  QTDPARTNOR    25149 non-null  float64
#  39  QTDPARTCES    25237 non-null  float64
#  40  IDADEPAI      7607 non-null   float64
#  41  DTULTMENST    16956 non-null  float64
#  42  SEMAGESTAC    25790 non-null  float64
#  43  TPMETESTIM    25790 non-null  float64
#  44  CONSPRENAT    26098 non-null  float64
#  45  MESPRENAT     24161 non-null  float64
#  46  TPAPRESENT    26763 non-null  float64
#  47  STTRABPART    26081 non-null  float64
#  48  STCESPARTO    26281 non-null  float64
#  49  TPNASCASSI    26967 non-null  float64
#  50  TPFUNCRESP    26961 non-null  float64
#  51  TPDOCRESP     27014 non-null  float64
#  52  DTDECLARAC    26976 non-null  float64
#  53  ESCMAEAGR1    26779 non-null  float64
#  54  STDNEPIDEM    27028 non-null  int64
#  55  STDNNOVA      27028 non-null  int64
#  56  CODPAISRES    27028 non-null  int64
#  57  TPROBSON      27028 non-null  int64
#  58  PARIDADE      27028 non-null  int64
#  59  KOTELCHUCK    27028 non-null  int64
#  60  CONTADOR      27028 non-null  int64
#  61  munResStatus  27028 non-null  object
#  62  munResTipo    27028 non-null  object
#  63  munResNome    27028 non-null  object
#  64  munResUf      27028 non-null  object
#  65  munResLat     27027 non-null  float64
#  66  munResLon     27027 non-null  float64
#  67  munResAlt     27027 non-null  float64
#  68  munResArea    27027 non-null  float64
# dtypes: float64(38), int64(16), object(15)
# memory usage: 14.2+ MB

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_raw.groupby('munResNome')[['IDADEMAE', 'IDADEPAI']].mean().round()
# Out:
#                            IDADEMAE  IDADEPAI
# munResNome
# Alta Floresta D'Oeste          26.0      30.0
# Alto Alegre dos Parecis        25.0      29.0
# Alto Paraíso                   25.0      29.0
# Alvorada D'Oeste               26.0      31.0
# Ariquemes                      26.0      32.0
# Buritis                        26.0      31.0
# Cabixi                         26.0      34.0
# Cacaulândia                    26.0      36.0
# Cacoal                         27.0      31.0
# Campo Novo de Rondônia         25.0      30.0
# Candeias do Jamari             25.0      30.0
# Castanheiras                   27.0      30.0
# Cerejeiras                     27.0      32.0
# Chupinguaia                    25.0      30.0
# Colorado do Oeste              28.0      34.0
# Corumbiara                     25.0      32.0
# Costa Marques                  24.0      31.0
# Cujubim                        24.0      31.0
# Espigão D'Oeste                26.0      31.0
# Governador Jorge Teixeira      24.0      29.0
# Guajará-Mirim                  25.0      30.0
# Itapuã do Oeste                26.0      42.0
# Jaru                           26.0      32.0
# Ji-Paraná                      26.0      31.0
# Machadinho D'Oeste             25.0      31.0
# Ministro Andreazza             28.0      34.0
# Mirante da Serra               26.0      32.0
# Monte Negro                    26.0      35.0
# Município ignorado - RO        24.0      22.0
# Nova Brasilândia D'Oeste       26.0      31.0
# Nova Mamoré                    25.0      32.0
# Nova União                     27.0      31.0
# Novo Horizonte do Oeste        27.0      32.0
# Ouro Preto do Oeste            26.0      31.0
# Parecis                        26.0      32.0
# Pimenta Bueno                  25.0      30.0
# Pimenteiras do Oeste           25.0      36.0
# Porto Velho                    26.0      32.0
# Presidente Médici              26.0      30.0
# Primavera de Rondônia          27.0      32.0
# Rio Crespo                     27.0      28.0
# Rolim de Moura                 27.0      30.0
# Santa Luzia D'Oeste            26.0      31.0
# Seringueiras                   25.0      30.0
# São Felipe D'Oeste             26.0      31.0
# São Francisco do Guaporé       26.0      32.0
# São Miguel do Guaporé          26.0      33.0
# Teixeirópolis                  26.0      32.0
# Theobroma                      26.0      30.0
# Urupá                          27.0      31.0
# Vale do Anari                  26.0      34.0
# Vale do Paraíso                26.0      30.0
# Vilhena                        26.0      34.0

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
dezesseis_dezembro = sinasc_raw[sinasc_raw['DTNASC'] == '2019-12-16']
dezesseis_dezembro
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 13813       1  2516500.0      110001        1        21        2.0
# 14921       1  2515520.0      110002        1        24        2.0
# 14950       1  2515504.0      110002        1        28        1.0
# 14951       1  2515504.0      110002        1        22        2.0
# 15006       1  2494299.0      110002        1        26        5.0
# ...       ...        ...         ...      ...       ...        ...
# 25969       1  2515989.0      110030        1        27        2.0
# 26503       1  5915104.0      110045        1        22        1.0
# 26537       1  5915104.0      110045        1        33        2.0
# 26595       1  3156516.0      110130        1        26        2.0
# 26958       1  2000733.0      120040        1        26        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 13813  12 anos ou mais    999994.0         1.0         0.0  ...           2
# 14921  12 anos ou mais    999992.0         0.0         1.0  ...           5
# 14950      8 a 11 anos    999992.0         1.0         0.0  ...           4
# 14951       4 a 7 anos    622020.0         1.0         0.0  ...           5
# 15006       4 a 7 anos    999992.0         2.0         1.0  ...           5
# ...                ...         ...         ...         ...  ...         ...
# 25969      8 a 11 anos    999992.0         2.0         0.0  ...           5
# 26503      8 a 11 anos    612005.0         1.0         NaN  ...           3
# 26537      8 a 11 anos    612005.0         1.0         NaN  ...           5
# 26595      8 a 11 anos    622020.0         0.0         0.0  ...           5
# 26958       4 a 7 anos    999992.0         1.0         NaN  ...           2
#
#       CONTADOR munResStatus munResTipo              munResNome  munResUf  \
# 13813  1480346        ATIVO      MUNIC          Rolim de Moura  Rondônia
# 14921  1481457        ATIVO      MUNIC               Ariquemes  Rondônia
# 14950  1481486        ATIVO      MUNIC               Ariquemes  Rondônia
# 14951  1481487        ATIVO      MUNIC             Porto Velho  Rondônia
# 15006  1481542        ATIVO      MUNIC               Ariquemes  Rondônia
# ...        ...          ...        ...                     ...       ...
# 25969  1492622        ATIVO      MUNIC              Cerejeiras  Rondônia
# 26503  1493157        ATIVO      MUNIC  Campo Novo de Rondônia  Rondônia
# 26537  1493192        ATIVO      MUNIC                 Buritis  Rondônia
# 26595  1493250        ATIVO      MUNIC              Nova União  Rondônia
# 26958  1500426        ATIVO      MUNIC             Porto Velho  Rondônia
#
#        munResLat munResLon  munResAlt  munResArea
# 13813  -11.72226 -61.78578      227.0    1457.888
# 14921   -9.90846 -63.03327      139.0    4426.571
# 14950   -9.90846 -63.03327      139.0    4426.571
# 14951   -8.76889 -63.83145       87.0   34096.394
# 15006   -9.90846 -63.03327      139.0    4426.571
# ...          ...       ...        ...         ...
# 25969  -13.19503 -60.81843      263.0    2783.300
# 26503  -10.56842 -63.62499      206.0    3442.005
# 26537  -10.20981 -63.82968      153.0    3265.809
# 26595  -10.91553 -62.55509      241.0     807.126
# 26958   -8.76889 -63.83145       87.0   34096.394
#
# [74 rows x 69 columns]

# %%
dezesseis_dezembro.groupby(['ESCMAE', 'SEXO'])[['PESO']].mean().round()
# Out:
#                              PESO
# ESCMAE          SEXO
# 1 a 3 anos      Feminino   3552.0
# 12 anos ou mais Feminino   3201.0
#                 Masculino  3487.0
# 4 a 7 anos      Feminino   3058.0
#                 Masculino  3595.0
# 8 a 11 anos     Feminino   3187.0
#                 Masculino  3069.0

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_raw['munResNome'].value_counts(ascending=True)
# Out:
# Município ignorado - RO         1
# Castanheiras                   32
# Pimenteiras do Oeste           40
# Primavera de Rondônia          43
# Parecis                        44
# Rio Crespo                     50
# São Felipe D'Oeste             54
# Teixeirópolis                  64
# Cacaulândia                    75
# Cabixi                         80
# Vale do Paraíso                81
# Ministro Andreazza             84
# Vale do Anari                  93
# Theobroma                      97
# Novo Horizonte do Oeste        98
# Santa Luzia D'Oeste            99
# Nova União                    104
# Itapuã do Oeste               109
# Governador Jorge Teixeira     112
# Corumbiara                    127
# Alto Alegre dos Parecis       154
# Chupinguaia                   162
# Mirante da Serra              164
# Campo Novo de Rondônia        166
# Seringueiras                  168
# Urupá                         170
# Monte Negro                   199
# Alvorada D'Oeste              205
# Cujubim                       205
# Colorado do Oeste             214
# Alto Paraíso                  226
# Costa Marques                 233
# Cerejeiras                    237
# Nova Brasilândia D'Oeste      261
# São Francisco do Guaporé      303
# Presidente Médici             304
# Candeias do Jamari            337
# São Miguel do Guaporé         353
# Alta Floresta D'Oeste         367
# Nova Mamoré                   432
# Espigão D'Oeste               450
# Machadinho D'Oeste            500
# Buritis                       583
# Pimenta Bueno                 616
# Ouro Preto do Oeste           631
# Guajará-Mirim                 781
# Jaru                          881
# Rolim de Moura                927
# Cacoal                       1374
# Vilhena                      1590
# Ariquemes                    1729
# Ji-Paraná                    2182
# Porto Velho                  8437
# Name: munResNome, dtype: int64

# %%
sinasc_1 = sinasc_raw[['IDADEMAE', 'IDADEPAI', 'munResNome']]
sinasc_mun_ignorado = sinasc_1[sinasc_1['munResNome'] == 'Município ignorado - RO']

# %%
sinasc_mun_ignorado.groupby('munResNome').aggregate([('média','mean'),('máxima','max'),('mínima','min')])
# Out:
#                         IDADEMAE               IDADEPAI
#                            média máxima mínima    média máxima mínima
# munResNome
# Município ignorado - RO       24     24     24     22.0   22.0   22.0

# %% [markdown]
# ##### Desconsiderando o Município Ignorado - RO que possuí apenas um resgistro, e utilizando o segundo município com a menor quantidade de bebês nascidos, Castanheiras, temos os seguintes resultados.

# %%
sinasc_castanheiras = sinasc_1[sinasc_1['munResNome'] == 'Castanheiras']
sinasc_castanheiras.groupby('munResNome').aggregate([('média','mean'),('máxima','max'),('mínima','min')]).round()
# Out:
#              IDADEMAE               IDADEPAI
#                 média máxima mínima    média máxima mínima
# munResNome
# Castanheiras     27.0     39     17     30.0   43.0   17.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_2 = sinasc_raw[['munResNome', 'DTNASC','IDADEMAE', 'IDADEPAI', 'QTDFILVIVO']]
sinasc_march = sinasc_2[sinasc_2['DTNASC'].str.contains('2019-03')]
sinasc_march.reset_index(inplace=True, drop=True)
sinasc_march
# Out:
#                    munResNome      DTNASC  IDADEMAE  IDADEPAI  QTDFILVIVO
# 0     Alto Alegre dos Parecis  2019-03-20        30      24.0         0.0
# 1       Alta Floresta D'Oeste  2019-03-23        30      27.0         1.0
# 2       Alta Floresta D'Oeste  2019-03-27        33      40.0         2.0
# 3       Alta Floresta D'Oeste  2019-03-11        30      41.0         1.0
# 4       Alta Floresta D'Oeste  2019-03-11        31      28.0         1.0
# ...                       ...         ...       ...       ...         ...
# 2451              Porto Velho  2019-03-21        24       NaN         0.0
# 2452              Porto Velho  2019-03-22        24       NaN         2.0
# 2453              Porto Velho  2019-03-07        35      42.0         1.0
# 2454                  Vilhena  2019-03-30        36       NaN         2.0
# 2455                Ji-Paraná  2019-03-09        31      50.0         0.0
#
# [2456 rows x 5 columns]

# %%
sinasc_march['munResNome'].value_counts(ascending= False)
# Out:
# Porto Velho                  744
# Ji-Paraná                    188
# Vilhena                      148
# Ariquemes                    141
# Cacoal                       133
# Jaru                          80
# Guajará-Mirim                 75
# Rolim de Moura                69
# Ouro Preto do Oeste           67
# Pimenta Bueno                 62
# Buritis                       59
# Nova Mamoré                   53
# Espigão D'Oeste               44
# Machadinho D'Oeste            44
# São Miguel do Guaporé         41
# Candeias do Jamari            33
# Alta Floresta D'Oeste         31
# São Francisco do Guaporé      31
# Presidente Médici             29
# Costa Marques                 24
# Alto Paraíso                  22
# Alvorada D'Oeste              22
# Monte Negro                   20
# Nova Brasilândia D'Oeste      20
# Colorado do Oeste             19
# Seringueiras                  19
# Chupinguaia                   18
# Cujubim                       17
# Cerejeiras                    16
# Urupá                         14
# Vale do Paraíso               13
# Campo Novo de Rondônia        13
# Corumbiara                    12
# Vale do Anari                 11
# Alto Alegre dos Parecis       10
# Cacaulândia                   10
# Governador Jorge Teixeira     10
# Rio Crespo                     9
# Mirante da Serra               9
# Theobroma                      8
# Itapuã do Oeste                8
# Santa Luzia D'Oeste            7
# Nova União                     7
# Pimenteiras do Oeste           6
# Ministro Andreazza             6
# Cabixi                         6
# Parecis                        6
# Primavera de Rondônia          5
# Novo Horizonte do Oeste        5
# São Felipe D'Oeste             5
# Castanheiras                   4
# Teixeirópolis                  3
# Name: munResNome, dtype: int64

# %%
sinasc_march_porto = sinasc_march[sinasc_march['munResNome'] == 'Porto Velho']
sinasc_march_porto.groupby('munResNome').agg([('média','mean'),('máxima','max'),('mínima','min')]).round(2)
# Out:
#             IDADEMAE               IDADEPAI               QTDFILVIVO         \
#                média máxima mínima    média máxima mínima      média máxima
# munResNome
# Porto Velho     26.6     44     14    34.63   62.0   19.0        1.3    9.0
#
#
#             mínima
# munResNome
# Porto Velho    0.0

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# 0      Masculino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 1       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 2       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 3       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# 4       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# ...          ...     ...         ...       ...        ...         ...
# 27023  Masculino  Branca  2020-09-28       NaN     3.2.01  2020-10-13
# 27024  Masculino  Branca  2019-10-16       NaN     3.2.01  2019-10-21
# 27025  Masculino   Parda  2019-08-07       NaN     3.2.00  2019-08-07
# 27026  Masculino   Parda  2020-01-07       NaN     3.2.00  2020-01-07
# 27027  Masculino   Parda  2020-10-15       NaN     3.2.01  2020-10-16
#
#       munResStatus munResTipo               munResNome  munResUf
# 0            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...            ...        ...                      ...       ...
# 27023        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
# [27028 rows x 15 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')

# %% [markdown]
# #### Mães com escolaridades maiores possuem uma média de filhos nascidos de acordo com a APGAR1 e APGAR5 mais saudáveis.

# %%
sinasc_raw[['ESCMAE', 'APGAR1', 'APGAR5']].groupby('ESCMAE').aggregate(['mean', 'max', 'min']).round(2)
# Out:
#                 APGAR1                  APGAR5
#                 median  mean   max  min median  mean   max  min
# ESCMAE
# 1 a 3 anos         8.0  7.93  10.0  0.0    9.0  8.98  10.0  1.0
# 12 anos ou mais    8.0  8.26  10.0  0.0    9.0  9.26  10.0  0.0
# 4 a 7 anos         8.0  8.06  10.0  0.0    9.0  9.12  10.0  0.0
# 8 a 11 anos        8.0  8.12  10.0  0.0    9.0  9.17  10.0  0.0
# Nenhuma            8.0  8.05   9.0  0.0    9.0  8.98  10.0  0.0

# %%
sinasc_raw[['IDADEMAE', 'APGAR1', 'APGAR5']].groupby('IDADEMAE').agg(['mean', 'max', 'min']).round(2)
# Out:
#          APGAR1            APGAR5
#            mean   max  min   mean   max  min
# IDADEMAE
# 11         8.00   8.0  8.0   9.00   9.0  9.0
# 12         6.71   9.0  2.0   8.29  10.0  6.0
# 13         7.77   9.0  0.0   8.92  10.0  0.0
# 14         7.98   9.0  3.0   9.07  10.0  5.0
# 15         7.97   9.0  1.0   9.09  10.0  2.0
# 16         8.04  10.0  2.0   9.12  10.0  0.0
# 17         8.04  10.0  1.0   9.12  10.0  0.0
# 18         8.06  10.0  0.0   9.11  10.0  0.0
# 19         8.08  10.0  0.0   9.14  10.0  0.0
# 20         8.12  10.0  0.0   9.19  10.0  1.0
# 21         8.11  10.0  0.0   9.17  10.0  0.0
# 22         8.13  10.0  2.0   9.19  10.0  5.0
# 23         8.15  10.0  0.0   9.20  10.0  1.0
# 24         8.13  10.0  0.0   9.19  10.0  0.0
# 25         8.15  10.0  0.0   9.17  10.0  0.0
# 26         8.18  10.0  0.0   9.21  10.0  0.0
# 27         8.15  10.0  0.0   9.16  10.0  1.0
# 28         8.18  10.0  1.0   9.21  10.0  0.0
# 29         8.21  10.0  1.0   9.22  10.0  0.0
# 30         8.21  10.0  0.0   9.23  10.0  1.0
# 31         8.20  10.0  0.0   9.24  10.0  1.0
# 32         8.20  10.0  2.0   9.21  10.0  4.0
# 33         8.24  10.0  0.0   9.21  10.0  1.0
# 34         8.16  10.0  0.0   9.19  10.0  1.0
# 35         8.17  10.0  1.0   9.18  10.0  2.0
# 36         8.09  10.0  0.0   9.19  10.0  4.0
# 37         8.13  10.0  0.0   9.13  10.0  1.0
# 38         8.17  10.0  1.0   9.20  10.0  6.0
# 39         8.10  10.0  1.0   9.20  10.0  6.0
# 40         8.03  10.0  1.0   9.13  10.0  1.0
# 41         8.12  10.0  3.0   9.13  10.0  4.0
# 42         7.92  10.0  0.0   9.05  10.0  0.0
# 43         8.05   9.0  7.0   9.05  10.0  8.0
# 44         8.09   9.0  4.0   9.11  10.0  4.0
# 45         8.25   9.0  8.0   9.12  10.0  9.0
# 46         7.60   9.0  6.0   8.80   9.0  8.0
# 47         8.60   9.0  8.0   9.60  10.0  9.0
# 51         8.00   8.0  8.0   9.00   9.0  9.0
# 52         8.00   8.0  8.0   9.00   9.0  9.0
# 53         8.50   9.0  8.0   9.50  10.0  9.0

# %% [markdown]
# #### Mulheres mais novas apresentaram em média tempo de gestação mais curto

# %%
sinasc_raw[['GESTACAO', 'IDADEMAE']].groupby('GESTACAO').agg(['mean', 'max', 'min']).round(2)
# Out:
#                     IDADEMAE
#                         mean
# GESTACAO
# 22 a 27 semanas        24.77
# 28 a 31 semanas        26.20
# 32 a 36 semanas        26.31
# 37 a 41 semanas        26.03
# 42 semanas e mais      24.86
# Menos de 22 semanas    22.86

# %%
sinasc_raw[['SEXO', 'PARTO', 'ORIGEM']].groupby(['SEXO', 'PARTO']).aggregate('count')
# Out:
#                    ORIGEM
# SEXO      PARTO
# Feminino  Cesáreo    8737
#           Vaginal    4372
# Masculino Cesáreo    9296
#           Vaginal    4570

# %%
sinasc_raw[['munResNome', 'SEXO', 'ORIGEM']].groupby(['munResNome', 'SEXO']).agg('count').sort_values(by = 'ORIGEM')
# Out:
#                                    ORIGEM
# munResNome              SEXO
# Município ignorado - RO Feminino        1
# Castanheiras            Masculino      14
# Parecis                 Masculino      17
# Castanheiras            Feminino       18
# Primavera de Rondônia   Feminino       18
# ...                                   ...
# Ariquemes               Masculino     952
# Ji-Paraná               Feminino     1085
#                         Masculino    1096
# Porto Velho             Feminino     4163
#                         Masculino    4272
#
# [105 rows x 1 columns]
